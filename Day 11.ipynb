# %%
import cv2
import matplotlib.pyplot as plt
import skimage as ski

# %%
img=cv2.imread("robot.jpg")
plt.imshow(img)

# %% [markdown]
# #image type coversion
# #geometric transportation
# #image arithematic /brigtjyness
# #morphological
# #fearture deletion
# plt.imshow(img,cmap='gray')

# %%
th,img_bin=cv2.threshold(img_gray,70,255,cv2.THRESH_BINARY)
img_bin.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 th,img_bin=cv2.threshold(img_gray,70,255,cv2.THRESH_BINARY)
#       2 img_bin.shape
#
# NameError: name 'img_gray' is not defined

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

im = cv2.imread('kkk.jpg',cv2.IMREAD_GRAYSCALE)

plt.imshow(im, cmap = 'gray', interpolation = 'bicubic')
# to hide tick values on X and Y axis
plt.imshow(im)

# %%
plt.imshow(im(0:200,200:400,::-1))
# Out:
#   Cell In[15], line 1
#     plt.imshow(im(0:200,200:400,::-1))
#                    ^
# SyntaxError: invalid syntax

# %%
img_x=ski.transform.rotate(img,-30)
plt.imshow(img_x[:,:,::-1])

# %%
#image airthmatic
#addition=brightness
#substraction=low brightness
plt.subplot(1,3,1)
plt.imshow(img[:,:,::-1])
plt.subplot(1,3,2)
plt.imshow(cv2.add(img[:,:,::-1],20));plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(cv2.subtract(img[:,:,::-1],20));plt.axis('off')
# Out:
# (-0.5, 909.5, 569.5, -0.5)

# %%
img2=cv2.imread("pic.jpeg")
plt.imshow(img2)

#alpha=contrast
#beta=brightness
img_cntbrt=cv2.convertScaleAbs(

       img2,alpha=10,beta=0

)
plt.imshow(img_cntbrt[:,:,::-1])
