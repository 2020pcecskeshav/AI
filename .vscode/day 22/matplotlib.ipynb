# %%
import matplotlib.pyplot as plt

# %%
#creating data set
x=(3,8,5,15)
x1=(4,9,6,16)
y=(5,13,7,21)
y1=(6,14,8,22)

#creating x-axis
plt.xlabel('x')
plt.ylabel('y')
plt.title('bachpan ki yade')
plt.scatter(x,y,marker='*',s=120,label='water')
plt.scatter(x1,y1,marker='^',s=120,label='soil')
plt.bar(x,y)
plt.bar(x1,y1)
plt.legend(loc='lower right')# to show labels of scatter
plt.plot(x,y)
plt.plot(x1,y1)


plt.grid()
plt.show()

# %%
name=['amit','rajander','atul','jaan']
runs=[100,20,50,23]


#condition list
name1=[]
run1=[]
for i in range(len(players)):
    if runs[i]>200:
        plt.append(players(i))
        plt.append(runs(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 8
#       6 name1=[]
#       7 run1=[]
# ----> 8 for i in range(len(players)):
#       9     if runs[i]>200:
#      10         plt.append(players(i))
#
# NameError: name 'players' is not defined

# %%
import numpy as np

# %%
phone_names=['apple','oneplus','google','lava']
sales=np.array([25,34,12,54])
myexplode = [0.2, 0.5, 0, 0]

#creating pia chart

plt.pie(sales,labels=phone_names,autopct='%1.1f%%',explode = myexplode)
plt.show()
