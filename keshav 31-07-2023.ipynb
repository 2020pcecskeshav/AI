# %%
# !python -m pip install numpy
# Out:
# ...
#                                               0.0/15.0 MB ? eta -:--:--
#                                               0.0/15.0 MB ? eta -:--:--
#                                              0.0/15.0 MB 393.8 kB/s eta 0:00:39
#                                              0.1/15.0 MB 819.2 kB/s eta 0:00:19
#                                              0.1/15.0 MB 722.1 kB/s eta 0:00:21
#                                              0.2/15.0 MB 888.4 kB/s eta 0:00:17
#                                              0.2/15.0 MB 901.1 kB/s eta 0:00:17
#                                              0.3/15.0 MB 874.6 kB/s eta 0:00:17
#                                              0.3/15.0 MB 774.0 kB/s eta 0:00:20
#                                              0.3/15.0 MB 791.9 kB/s eta 0:00:19
#                                              0.3/15.0 MB 723.4 kB/s eta 0:00:21
#                                              0.4/15.0 MB 742.3 kB/s eta 0:00:20
# ...

# %%
import numpy as np

# %%
a=np.array([3,2,33,22,33])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
print(a.shape)
print(a.size)
print(a.dtype)
# Out:
# (5,)
# 5
# int32

# %%
def show_array(arr):
    print('Array:',arr,sep='\n')
    print('type:',type(arr))
    print('Shape:',arr.shape)
    print('size',arr.size)

# %%
import numpy as np

# %%
b=np.array([[[5,10],[6,10],[9,30],[5,20],[9,6],[90,9],[6,20],[6,60]]])

# %%
print(b)
# Out:
# [[[ 5 10]
#   [ 6 10]
#   [ 9 30]
#   [ 5 20]
#   [ 9  6]
#   [90  9]
#   [ 6 20]
#   [ 6 60]]]

# %%
print(b.shape)
# Out:
# (1, 8, 2)

# %%
#subscripting [1st,2nd,3rd,.........nthdim]
#sunscripting [1st:1st end: stepsize,2nd , 3rd ,.......nth dim]
#slice maintain stucture
import numpy as np

# %%
c=np.array([[10,20,30,40],[20,6,0,222],[10,5,0,6]])

# %%
print(c)
# Out:
# [[ 10  20  30  40]
#  [ 20   6   0 222]
#  [ 10   5   0   6]]

# %%
c[2][0:]
# Out:
# array([10,  5,  0,  6])

# %%
d=np.array([[[10,100],[11,110],[13,130],[14,140]],[[45,145],[22,122],[9,19],[2,12]],[[6,16],[5,15],[1,11],[8,18]]])

# %%
print(d)
# Out:
# [[[ 10 100]
#   [ 11 110]
#   [ 13 130]
#   [ 14 140]]
#
#  [[ 45 145]
#   [ 22 122]
#   [  9  19]
#   [  2  12]]
#
#  [[  6  16]
#   [  5  15]
#   [  1  11]
#   [  8  18]]]

# %%
d[0][1][1:]
d[1:]
# Out:
# array([[[ 45, 145],
#         [ 22, 122],
#         [  9,  19],
#         [  2,  12]],
#
#        [[ 23,   5],
#         [ 22,  99],
#         [ 33,  66],
#         [ 88,  99]]])

# %%
print(d[:1,:2,:])
# Out:
# [[[ 10 100]
#   [ 11 110]]]

# %%
d[:,1:2,:1]
# Out:
# array([[[11]],
#
#        [[22]],
#
#        [[ 5]]])

# %%
d[-2:,-1:,:1]
# Out:
# array([[[2]],
#
#        [[8]]])

# %%
d[:2,-2:,:]
# Out:
# array([[[ 13, 130],
#         [ 14, 140]],
#
#        [[  9,  19],
#         [  2,  12]]])

# %%
#item assingment
print(c)
# Out:
# [[ 10  20  30  40]
#  [ 20   6   0 222]
#  [ 10   5   0   6]]

# %%
c[1,1]=10

# %%
print(c)
# Out:
# [[ 10  20  30  40]
#  [ 20  10   0 222]
#  [ 10   5   0   6]]

# %%
#item insertion

# %%
a=np.array([10,2,2,00])

# %%
print(a)
# Out:
# [10  2  2  0]

# %%
np.append(a,80)
# Out:
# array([10,  2,  2,  0, 80])

# %%
print(d)
# Out:
# [[[ 10 100]
#   [ 11 110]
#   [ 13 130]
#   [ 14 140]]
#
#  [[ 45 145]
#   [ 22 122]
#   [  9  19]
#   [  2  12]]
#
#  [[  6  16]
#   [  5  15]
#   [  1  11]
#   [  8  18]]]

# %%
#deleation
np.delete(a,0,axis=0)
# Out:
# array([2, 2, 0])

# %%
#airthmetic

# %%
#numpy is different as list
a +20
# Out:
# array([30, 22, 22, 20])

# %%
a *a
# Out:
# array([100,   4,   4,   0])

# %%
#array mainupulation 
#more function to create array
a.reshape(2,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 3
#       1 #array mainupulation
#       2 #more function to create array
# ----> 3 a.reshape(2,1)
#
# ValueError: cannot reshape array of size 4 into shape (2,1)

# %%
b.astype(float)
# Out:
# array([[[ 5., 10.],
#         [ 6., 10.],
#         [ 9., 30.],
#         [ 5., 20.],
#         [ 9.,  6.],
#         [90.,  9.],
#         [ 6., 20.],
#         [ 6., 60.]]])
